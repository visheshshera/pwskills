# %% [markdown]
# # EDA FINAL ANSWER

# %% [markdown]
# # EDA 1

# %% [markdown]
# Ques 1 What is the range of selling prices in the dataset?
# Ques 2 What is the median selling price for bikes in the dataset?
# Ques 3 What is the most common seller type?
# Ques 4 How many bikes have driven more than 50,000 kilometers?
# Ques 5 What is the average km_driven value for each ownership type?
# Ques 6 What proportion of bikes are from the year 2015 or older?
# Ques 7 What is the trend of missing values across the dataset?
# Ques 8 What is the highest ex_showroom_price recorded, and for which bike?
# Ques 9 What is the total number of bikes listed by each seller type?
# Ques 10 What is the relationship between selling_price and km_driven for first-owner bikes?
# Ques 11 Identify and remove outliers in the km_driven column using the IQR method.
# Ques 12 Perform a bivariate analysis to visualize the relationship between year and selling_price.
# Ques 13 What is the average depreciation in selling price based on the bike's age (current year - manufacturing year)?
# Ques 14 Which bike names are priced significantly above the average price for their manufacturing year?
# Ques 15 Develop a correlation matrix for numeric columns and visualize it using a heatmap.

# %% [markdown]
# Answers for Question 1
#
# Ans 1 (5000-760000) is the range of price of car.
#
# Ans 2 45000 is the median selling price for bikes
#
# Ans 3 Individual is the most common seller type with 1055 counts
#
# Ans 4 170
#
# Ans 5   1st owner     32732.710240
#         2nd owner     39288.991870
#         3rd owner     33292.181818
#         4th owner    311500.000000
#
# Ans 6 52.8%
#
# Ans 7 exshowroom price is missing in dataset
#
# Ans 8 Harley-Davidson Street Bob is the highest listed bike in terms of exshowroom price with 1278000
#
# Ans 9 Individual:1055 Dealer: 6
#
# Ans 10![image-2.png](attachment:image-2.png)
#
# Ans 11
# Q1 = first_owner_bikes['km_driven'].quantile(0.25)
# Q3 = first_owner_bikes['km_driven'].quantile(0.75)
# IQR = Q3 - Q1
#
# lower_bound = Q1 - 1.5 * IQR
# upper_bound = Q3 + 1.5 * IQR
#
# first_owner_bikes_no_outliers = first_owner_bikes[
#     (first_owner_bikes['km_driven'] >= lower_bound) & (first_owner_bikes['km_driven'] <= upper_bound)
# ]
#
# print(f"Number of outliers removed: {len(first_owner_bikes) - len(first_owner_bikes_no_outliers)}")
#
# first_owner_bikes_no_outliers
#
# Ans 12![image.png](attachment:image.png)
#
# Ans 13
# bike_age depreciation
# 4	4560.725191
# 5	15149.816218
# 6	16622.338968
# 7	23233.906023
# 8	25497.646412
# 9	30985.729943
# 10	34379.687911
# 11	41735.760228
# 12	45344.222209
# 13	49806.443905
# 14	53505.110024
# 15	54259.220659
# 16	55235.978331
# 17	56472.100694
# 18	68710.166054
# 19	60991.196141
# 20	80060.794212
# 21	67394.127546
#
#
# Ans 14  ['Royal Enfield Classic Gunmetal Grey', 'Yamaha Fazer FI V 2.0 [2016-2018]', 'Bajaj Avenger Street 220', 'Yamaha YZF R3', 'Yamaha YZF R15 S', 'Royal Enfield Classic Gunmetal Grey', 'Yamaha FZ25', 'Honda CBR-250R', 'Honda CB Hornet 160R', 'Mahindra Mojo XT300', 'Bajaj Pulsar AS200', 'Royal Enfield Thunderbird 350X', 'Royal Enfield Classic Gunmetal Grey', 'Yamaha FZ25', 'Royal Enfield Classic Desert Storm', 'Yamaha FZ25', 'UM Renegade Commando', 'Royal Enfield Classic Gunmetal Grey', 'Harley-Davidson Street Bob', 'Royal Enfield Classic Gunmetal Grey', 'KTM 390 Duke ABS [2013-2016]', 'Honda CB Hornet 160R', 'Royal Enfield Classic 500', 'Royal Enfield Classic Desert Storm', 'Honda CB Hornet 160R', 'Yamaha YZF R15 [2011-2018]', 'Bajaj Pulsar AS200', 'Royal Enfield Bullet 500', 'Bajaj Pulsar AS200', 'Bajaj Dominar 400 [2018]', 'Honda CB Hornet 160R', 'Roy
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # EDA 2

# %% [markdown]
# Ques 1 What is the average selling price of cars for each dealer, and how does it compare across different dealers?
# Ques 2 Which car brand (Company) has the highest variation in prices, and what does this tell us about the pricing trends?
# Ques 3 What is the distribution of car prices for each transmission type, and how do the interquartile ranges compare?
# Ques 4 What is the distribution of car prices across different regions?
# Ques 5 What is the distribution of cars based on body styles?
# Ques 6 How does the average selling price of cars vary by customer gender and annual income?
# Ques 7 What is the distribution of car prices by region, and how does the number of cars sold vary by region?
# Ques 8 How does the average car price differ between cars with different engine sizes?
# Ques 9 How do car prices vary based on the customer’s annual income bracket?
# Ques 10 What are the top 5 car models with the highest number of sales, and how does their price distribution look?
# Ques 11 How does car price vary with engine size across different car colors, and which colors have the highest price variation?
# Ques 12 Is there any seasonal trend in car sales based on the date of sale?
# *Ques 13 How does the car price distribution change when considering different combinations of body style and transmission type?
# Ques 14 What is the correlation between car price, engine size, and annual income of customers, and how do these features interact?
# Ques 15 How does the average car price vary across different car models and engine types?

# %% [markdown]
# Ans 1
#         U-Haul CO                                          28769.919006
#         Classic Chevy                                      28602.014446
#         Rabun Used Car Sales                               28527.536177
#         Iceberg Rentals                                    28522.958533
#         Enterprise Rent A Car                              28312.580800
#         Scrivener Performance Engineering                  28297.371589
#         Gartner Buick Hyundai Saab                         28247.621019
#         Saab-Belle Dodge                                   28190.139888
#         Capitol KIA                                        28189.703822
#         Race Car Help                                      28163.372706
#         Chrysler of Tri-Cities                             28123.091054
#         Star Enterprises Inc                               28113.055244
#         Suburban Ford                                      28112.206758
#         C & M Motors Inc                                   28111.755200
#         Tri-State Mack Inc                                 28095.562050
#         Pars Auto Sales                                    28013.060317
#         Diehl Motor CO Inc                                 27993.929487
#         Motor Vehicle Branch Office                        27956.739617
#         Ryder Truck Rental and Leasing                     27914.988782
#         Progressive Shippers Cooperative Association No    27884.264036
#         New Castle Ford Lincoln Mercury                    27867.131955
#         Hatfield Volkswagen                                27853.712242
#         Nebo Chevrolet                                     27818.889415
#         Clay Johnson Auto Sales                            27816.027113
#         McKinney Dodge Chrysler Jeep                       27684.096979
#         Chrysler Plymouth                                  27555.526400
#         Pitre Buick-Pontiac-Gmc of Scottsdale              27404.248408
#         Buddy Storbeck's Diesel Service Inc                27217.261563
#
#
# Ans 2   lincoln has highest price variation.
#
# Ans 3   Interquartile Range (IQR) for Manual Transmission: 17000.0
#         Interquartile Range (IQR) for Automatic Transmission: 16500.0
#         ![image.png](attachment:image.png)
#
# Ans 4   ![image-2.png](attachment:image-2.png)
#
# Ans 5   ![image-3.png](attachment:image-3.png)
#
# Ans 6   ![image-4.png](attachment:image-4.png)
#
# Ans 7   ![image-5.png](attachment:image-5.png)
#
# Ans 8   ![image-6.png](attachment:image-6.png)
#
# Ans 9   ![image-7.png](attachment:image-7.png)
#
# Ans 10
# Model           no of cars
# Diamante	418
# Silhouette	411
# Prizm	        411
# Passat	        391
# Ram Pickup	383
#
# ![image-8.png](attachment:image-8.png)
#
# Ans 11  ![image-9.png](attachment:image-9.png),
#
# black has highest price variation
#
# Ans 12  ![image-10.png](attachment:image-10.png)
#
# Ans 13  ![image-13.png](attachment:image-13.png)
#
# Ans 14 Correlation Matrix:
#                   Price  Engine_Size  Annual Income
# Price          1.000000     0.011271       0.012065
# Engine_Size    0.011271     1.000000       0.006598
# Annual Income  0.012065     0.006598       1.000000
#
#  ![image-11.png](attachment:image-11.png)
#
# Ans 15  ![image-12.png](attachment:image-12.png)

# %% [markdown]
# # EDA 3

# %% [markdown]
# Ques 1 What is the average rating for each product category?
# Ques 2 What are the top rating_count products by category?
# Ques 3 What is the distribution of discounted prices vs. actual prices?
# Ques 4 How does the average discount percentage vary across categories?
# Ques 5 What are the most popular product names?
# *Ques 6 What are the most popular product keywords?
# Ques 7 What are the most popular product reviews?
# Ques 8 What is the correlation between discounted_price and rating?
# Ques 9 What are the Top 5 categories based on the highest ratings?
# *Ques 10 Identify any potential areas for improvement or optimization based on the data analysis.

# %% [markdown]
# Ans 1 ![image-4.png](attachment:image-4.png)
#
# Ans 2  'Electronics', 'AmazonBasics Flexible Premium HDMI Cable (Black, 4K@60Hz, 18Gbps), 3-Foot',
#  'Home&Kitchen','Pigeon Polypropylene Mini Handy and Compact Chopper with 3 Blades for Effortlessly Chopping Vegetables and Fruits for Your Kitchen (12420, Green, 400 ml)',
#
#  'Computers&Accessories','SanDisk Cruzer Blade 32GB USB Flash Drive',
#
#  'MusicalInstruments','Boya ByM1 Auxiliary Omnidirectional Lavalier Condenser Microphone with 20ft Audio Cable (Black)',
#
#  'Toys&Games','Faber-Castell Connector Pen Set - Pack of 25 (Assorted)',
#
#  'OfficeProducts', 'Casio FX-82MS 2nd Gen Non-Programmable Scientific Calculator, 240 Functions and 2-line Display, Black',
#
#  'HomeImprovement','Gizga Essentials Cable Organiser, Cord Management System for PC, TV, Home Theater, Speaker & Cables, Reusable Cable Organizer for Desk, WFH Accessories, Organizer Tape Roll, Reusable Cable Ties Strap'
#
#  'Health&PersonalCare','Dr Trust Electronic Kitchen Digital Scale Weighing Machine (Blue)',
#
#  'Car&Motorbike', 'Reffair AX30 [MAX] Portable Air Purifier for Car, Home & Office | Smart Ionizer Function | H13 Grade True HEPA Filter [Internationally Tested] Aromabuds Fragrance Option - Black'
#
#
#
# Ans 3 ![image-2.png](attachment:image-2.png)
#
# Ans 4 ![image-3.png](attachment:image-3.png)
#
# Ans 5 Top 5 most famous nameare:-
#       a) Fire-Boltt Ninja Call Pro Plus 1.83" Smart Watch with Bluetooth Calling, AI Voice Assistance, 100 Sports Modes IP67 Rating, 240*280 Pixel High Resolution
#       b) Fire-Boltt Phoenix Smart Watch with Bluetooth Calling 1.3",120+ Sports Modes, 240*240 PX High Res with SpO2, Heart Rate Monitoring & IP67 Rating
#       c) Amazonbasics Nylon Braided Usb-C To Lightning Cable, Fast Charging Mfi Certified Smartphone, Iphone Charger (6-Foot, Dark Grey)
#       d) Duracell USB Lightning Apple Certified (Mfi) Braided Sync & Charge Cable For Iphone, Ipad And Ipod. Fast Charging Lightning Cable, 3.9 Feet (1.2M) - Black
#       e) Flix Micro Usb Cable For Smartphone (Black)
#
# Ans 6
#
# Ans 7 "Worked on iPhone 7 and didn’t work on XR,Good one,Dull Physical Looks,Just Buy it,Go for it,About the product,Get charging cable at the price,Working well." occured 10 times
#
# Ans 8 ![image.png](attachment:image.png)
#
# Ans 9 category                  rating
#       OfficeProducts           4.309677
#       Toys&Games               4.300000
#       HomeImprovement          4.250000
#       Computers&Accessories    4.154967
#       Electronics              4.081749
#
# Ans 10

# %% [markdown]
# # EDA 4

# %% [markdown]
# Ques 1 Read the dataframe, check null value if present then do the needful, check duplicate row , if present then do the needful.
# Ques 2 What is the distribution of popularity among the tracks in the dataset? Visualize it using a histogram.
# Ques 3 Is there any relationship between the popularity and the duration of tracks? Explore this using a scatter plot.
# Ques 4 Which artist has the highest number of tracks in the dataset? Display the count of tracks for each artist using a countplot.
# Ques 5 What are the top 5 least popular tracks in the dataset? Provide the artist name and track name for each.
# Ques 6 Among the top 5 most popular artists, which artist has the highest popularity on average? Calculate and display the average popularity for each artist.
# Ques 7 For the top 5 most popular artists, what are their most popular tracks? List the track name for each artist.
# Ques 8 Visualize relationships between multiple numerical variables simultaneously using a pair plot.
# Ques 9 Does the duration of tracks vary significantly across different artists? Explore this visually using a box plot or violin plot.
# Ques 10 How does the distribution of track popularity vary for different artists? Visualize this using a swarm plot or a violin plot.

# %% [markdown]
# Ans 1   df.read("spotify.csv")
#
# 		df.iSna().sum() #null values not present
#
# 		df.duplicated().sum()
# 		df.drop_duplicates(inplace=True)
#
# Ans 2 ![image.png](attachment:image.png)
#
# Ans 3 ![image-2.png](attachment:image-2.png)
#
# Ans 4 Drake has the highest number of tracks in the dataset.![image-3.png](attachment:image-3.png)
#
# Ans 5   Pressa	Attachments (feat. Coi Leray)
#         Justin Bieber	Intentions
#         French Montana	Splash Brothers
#         Lil Baby	    On Me - Remix
#         Wyclef Jean	    911 (feat. Mary J. Blige)
#
# Ans 6	![image-7.png](attachment:image-7.png)
#
# Ans 7 	Artist	            Track Name
#
# 	    Jack Harlow	        Lovin On Me
# 	    21 Savage	        redrum
# 	    ¥$	                CARNIVAL
# 	    Travis Scott	    FE!N (feat. Playboi Carti)
# 	    Drake	            Rich Baby Daddy (feat. Sexyy Red & SZA)
#
# Ans 8	![image-6.png](attachment:image-6.png)
#
# Ans 9	![image-4.png](attachment:image-4.png)
#
# Ans 10 ![image-5.png](attachment:image-5.png)
