# %% [markdown]
# Ans1) The five key concepts of Object-Oriented Programming (OOP) are:
#         a)polymorphism
#         b)abstraction
#         c)inheritence
#         d)encapsulation
#         e)classes and object
#
# Ans2)class Car:
#         def __init__(self,make,model,year):
#             self.make=make
#             self.model=model
#             self.year=year
#
#         def info(self):
#             print(self.make,self.model,self.year)
#      c1=Car("hyundai","creta","2022")
#      c1.run()
#
# Ans3)Instance Methods:
#
#          1. Bound to an instance of the class.
#          2. Can access and modify instance attributes.
#          3. Typically used for actions that involve a specific instance.
#
#      Class Methods:
#
#          1. Bound to the class itself.
#          2. Can access and modify class attributes.
#          3. Typically used for actions that involve the class as a whole.
#
#       COMMON EXAMPLE:
#             class Dog:
#                   species = "Canine"  # Class attribute
#
#             def __init__(self, name, age):
#                 self.name = name  # Instance attribute
#                       self.age = age    # Instance attribute
#
#             # Instance method
#             def bark(self):
#                       print(f"{self.name} is barking.")
#
#             # Class method
#             @classmethod
#             def get_species(cls):
#                 print(f"All dogs are {cls.species}.")
#
#             dog1 = Dog("Buddy", 3)
#
#             # Calling an instance method
#             dog1.bark()
#
#             # Calling a class method
#             Dog.get_species()
#
# Ans4)python does not support method overloading but it is achieved by several ways
#     for example:
#             def calculate(self, *args):
#                 if len(args) == 1:
#                     return args[0] ** 2
#                 elif len(args) == 2:
#                     return args[0] + args[1]
#                 else:
#                     return "Invalid number of arguments"
#
#
#             calculator = Calculator()
#             print(calculator.calculate(5))
#             print(calculator.calculate(3, 4))
#
# Ans5)Types of access modifiers in python:
#
#      •public
#         example:self.public_var
#      •private
#         example:self.__private_var
#      •protected
#         example:self._protected_var
#
#
# Ans6)Types of inheritence in python:
#      1. Single Inheritance
#      2. Multiple Inheritance
#      3. Multilevel Inheritance
#      4. Hierarchical Inheritance
#      5. Hybrid Inheritance
#
#      example of multiple inheritence:
#
#
#         class Engine:
#             def start(self):
#                 print("Engine starting")
#
#
#         class Wheels:
#             def rotate(self):
#                 print("Wheels rotating")
#
#
#         class Car(Engine, Wheels):
#             def drive(self):
#                 print("Car driving")
#
#         car = Car()
#         car.start()
#         car.rotate()
#         car.drive()
#
#
# Ans7)The Method Resolution Order (MRO) is the order in which Python searches for methods in a class's
# inheritance graph. It's used to resolve method calls when multiple classes in the inheritance hierarchy define methods with the same name.
#
# example:class A:
#             pass
#
#         class B(A):
#             pass
#
#         class C(B):
#             pass
#
#         print(C.mro())
#
#
# Ans8)import abc
#      class Shape:
#              @abc.abstractmethod
#          def calculate_area(self):
#              pass
#      class Rectangle(Shape):
#          def calculate_area(self):
#              return "Area of rectange is len*breadth"
#      class Circle(Shape):
#          def calculate_area(self):
#              return "area of circle is pi*r**2"
#      c = Circle()
#      c.calculate_area()
#
# Ans9)import math
#
#
#      def circle_area():
#          return math.pi * 5 ** 2
#
#      def rectangle_area():
#          return 4 * 6
#
#      def triangle_area():
#          return 0.5 * 3 * 7
#
#      def calculate_area(shape):
#          return shape()
#
#      def print_area(shape, name):
#          print(f"Area of {name}: {calculate_area(shape)}")
#
#
#      print_area(circle_area, 'Circle')
#      print_area(rectangle_area, 'Rectangle')
#      print_area(triangle_area, 'Triangle')
#
#
# Ans10)class Bank:
#
#           def __init__(self, balance):
#               self.__balance = balance
#
#           def deposit(self, amount): #amount is new deposition
#               self.__balance = self.__balance + amount
#
#           def withdraw(self, amount):
#               if self.__balance >= amount:
#                   self.__balance = self.__balance - amount
#                   return True
#               else:
#                   return False
#
#           def get_balance(self):
#               return self.__balance
#       acc1 = Bank(25000)
#       acc1.get_balance()
#       acc1.deposit(1550)
#       acc1.get_balance()
#       acc1.withdraw(10040)
#       acc1.get_balance()
#
# Ans11)class Vector:
#           def __init__(self, x, y):
#               self.x = x
#               self.y = y
#
#
#           def __str__(self):
#               return f"Vector({self.x}, {self.y})"
#
#
#           def __add__(self, other):
#               if isinstance(other, Vector):
#                   return Vector(self.x + other.x, self.y + other.y)
#               else:
#                   raise TypeError("Unsupported operand type for +")
#
#
#       # Create vectors
#       v1 = Vector(2, 3)
#       v2 = Vector(4, 5)
#
#
#       # Use __str__ method
#       print(v1)  # Output: Vector(2, 3)
#
#
#       # Use __add__ method
#       v3 = v1 + v2
#       print(v3)  # Output: Vector(6, 8)
#
#
# Ans12) from functools import wraps
#        import time
#
#
#        def timeit(func):
#            @wraps(func)
#            def timeit_wrapper(*args, **kwargs):
#                start_time = time.perf_counter()
#                result = func(*args, **kwargs)
#                end_time = time.perf_counter()
#                total_time = end_time - start_time
#                print(f'Function {func.__name__}{args} {kwargs} Took {total_time:.4f} seconds')
#                return result
#            return timeit_wrapper
#
#
#        @timeit
#        def calculate_something(num):
#            """
#            Simple function that returns sum of all numbers up to the square of num.
#            """
#            total = sum((x for x in range(0, num**2)))
#            return total
#
#        if __name__ == '__main__':
#            calculate_something(10)
#            calculate_something(100)
#
#
# Ans13) The Diamond Problem is a classic issue in multiple inheritance, where a class inherits conflicting methods or attributes from its parent classes. This creates a diamond-shaped inheritance graph.
# Python uses a depth-first left-to-right (DFLR) approach to resolve method calls.
#
# Ans14) class InstanceTracker:
#           instances = 0
#
#
#           def __init__(self):
#               InstanceTracker.instances += 1
#
#
#           @classmethod
#           @property
#           def instance_count(cls):
#               return cls.instances
#
#
#        # Create instances
#        obj1 = InstanceTracker()
#        obj2 = InstanceTracker()
#        obj3 = InstanceTracker()
#
#
#        # Print instance count
#        print(InstanceTracker.instance_count)
#
# Ans15) class DateUtil:
#            @staticmethod
#            def is_leap_year(year):
#                return year % 4 == 0 and (year % 100 != 0 or year % 400 == 0)
#
#
#        print(DateUtil.is_leap_year(2020))
#        print(DateUtil.is_leap_year(2019))
